# %% [markdown]
# # Multi-class Classification (Simple Example)

# %% [markdown]
# <figure>
#  <img src="./images/C2_W2_mclass_header.png"   style="width600px;height:400px;">
# </figure>

# %% [markdown]
# ## 1.2 Tools
#
# The plotting routines are stored in `lab_utils_multiclass_TF.py` in this directory.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib widget
from sklearn.datasets import make_blobs
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

np.set_printoptions(precision=2)
from lab_utils_multiclass_TF import *
import logging
logging.getLogger("tensorflow").setLevel(logging.ERROR)
tf.autograph.set_verbosity(0)

# %% [markdown]
# # 2.0 Multi-class Classification
# Neural Networks are often used to classify data. Examples are neural networks:
# - take in photos and classify subjects in the photos as {dog,cat,horse,other}
# - take in a sentence and classify the 'parts of speech' of its elements: {noun, verb, adjective etc..}
#
# A network of this type will have multiple units in its final layer. Each output is associated with a category. When an input example is applied to the network, the output with the highest value is the category predicted. If the output is applied to a softmax function, the output of the softmax will provide probabilities of the input being in each category.
#
# Let's start by creating a four-class data set.

# %% [markdown]
# ## 2.1 Prepare and visualize our data
# We will use Scikit-Learn `make_blobs` function to make a training data set with 4 categories as shown in the plot below.

# %%
# Make 4-class dataset for classification
classes = 4
m = 100
centers = [[-5, 2], [-2, -2], [1, 2], [5, -2]]
std = 1.0
X_train, y_train = make_blobs(n_samples=m, centers=centers, cluster_std=std,random_state=30)

# %%
plt_mc(X_train,y_train,classes, centers, std=std)
# Out:
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %% [markdown]
# Each dot represents a training example. The axis (x0,x1) are the inputs and the color represents the class the example is associated with. Once trained, the model will be presented with a new example, (x0,x1), and will predict the class.
#
# While generated, this data set is representative of many real-world classification problems. There are several input features (x0,...,xn) and several output categories. The model is trained to use the input features to predict the correct output category.

# %%
# Show classes in data set
print(f"unique classes {np.unique(y_train)}")
# Show how classes are represented
print(f"class representation {y_train[:10]}")
# Show shapes of our dataset
print(f"shape of X_train: {X_train.shape}, shape of y_train: {y_train.shape}")
# Out:
# unique classes [0 1 2 3]
# class representation [3 3 3 0 3 3 3 3 2 0]
# shape of X_train: (100, 2), shape of y_train: (100,)

# %% [markdown]
# ## 2.2 Model
#
# <center>  <img  src="./images/C2_W2_mclass_lab_network.PNG" width="800" />  </center>
#
# There would be two layers for this neural network. Unlike the binary classification networks, this network has four outputs, one for each class. Given an input example or row of features, the output with the highest value is the predicted class of the input.
#
# Notice again that the output layer uses a `linear` rather than a `softmax` activation, which makes our model more numerically stable if linear outputs are passed to the loss function during training. If the model is used to predict probabilities, then we can use `softmax` to convert the logit values to probabilities.

# %%
tf.random.set_seed(1234)  # For reproducibility
model = Sequential(
    [
        Dense(2, activation = 'relu',   name = "L1"),
        Dense(4, activation = 'linear', name = "L2")
    ]
)

# %% [markdown]
# The statements below compile and train the network. Setting `from_logits=True` as an argument to the loss function specifies that the output activation was linear rather than a softmax.

# %%
model.compile(
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),
)

model.fit(
    X_train,y_train,
    epochs=200 # The number of iterations over the entire dataset to train on
)
# Out:
# Epoch 1/200
# 4/4 [==============================] - 0s 2ms/step - loss: 2.7548
# Epoch 2/200
# 4/4 [==============================] - 0s 2ms/step - loss: 2.4569
# Epoch 3/200
# 4/4 [==============================] - 0s 2ms/step - loss: 2.2292
# Epoch 4/200
# 4/4 [==============================] - 0s 2ms/step - loss: 1.9987
# Epoch 5/200
# 4/4 [==============================] - 0s 2ms/step - loss: 1.8340
# Epoch 6/200
# 4/4 [==============================] - 0s 3ms/step - loss: 1.6822
# Epoch 7/200
# 4/4 [==============================] - 0s 2ms/step - loss: 1.5441
# Epoch 8/200
# 4/4 [==============================] - 0s 23ms/step - loss: 1.4090
# Epoch 9/200
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3079
# Epoch 10/200
# 4/4 [==============================] - 0s 3ms/step - loss: 1.2400
# Epoch 11/200
# 4/4 [==============================] - 0s 2ms/step - loss: 1.1906
# Epoch 12/200
# 4/4 [==============================] - 0s 2ms/step - loss: 1.1569
# Epoch 13/200
# 4/4 [==============================] - 0s 2ms/step - loss: 1.1307
# Epoch 14/200
# 4/4 [==============================] - 0s 2ms/step - loss: 1.1087
# Epoch 15/200
# 4/4 [==============================] - 0s 2ms/step - loss: 1.0877
# Epoch 16/200
# 4/4 [==============================] - 0s 2ms/step - loss: 1.0698
# Epoch 17/200
# 4/4 [==============================] - 0s 2ms/step - loss: 1.0513
# Epoch 18/200
# 4/4 [==============================] - 0s 2ms/step - loss: 1.0307
# Epoch 19/200
# 4/4 [==============================] - 0s 2ms/step - loss: 1.0091
# Epoch 20/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.9881
# Epoch 21/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.9692
# Epoch 22/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.9508
# Epoch 23/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.9305
# Epoch 24/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.9123
# Epoch 25/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.8917
# Epoch 26/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.8727
# Epoch 27/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8525
# Epoch 28/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.8331
# Epoch 29/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8138
# Epoch 30/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7939
# Epoch 31/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7732
# Epoch 32/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7531
# Epoch 33/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7322
# Epoch 34/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7136
# Epoch 35/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6950
# Epoch 36/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6773
# Epoch 37/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6615
# Epoch 38/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6460
# Epoch 39/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6313
# Epoch 40/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6179
# Epoch 41/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.6048
# Epoch 42/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5932
# Epoch 43/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5815
# Epoch 44/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5709
# Epoch 45/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5606
# Epoch 46/200
# 4/4 [==============================] - 0s 12ms/step - loss: 0.5514
# Epoch 47/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5421
# Epoch 48/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5339
# Epoch 49/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5261
# Epoch 50/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5186
# Epoch 51/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5121
# Epoch 52/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5057
# Epoch 53/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4995
# Epoch 54/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4936
# Epoch 55/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4874
# Epoch 56/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4812
# Epoch 57/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4754
# Epoch 58/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4699
# Epoch 59/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4642
# Epoch 60/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4587
# Epoch 61/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4533
# Epoch 62/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4480
# Epoch 63/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4426
# Epoch 64/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4367
# Epoch 65/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4309
# Epoch 66/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4256
# Epoch 67/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4195
# Epoch 68/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4137
# Epoch 69/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4081
# Epoch 70/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4008
# Epoch 71/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3944
# Epoch 72/200
# 4/4 [==============================] - 0s 16ms/step - loss: 0.3877
# Epoch 73/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3805
# Epoch 74/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3743
# Epoch 75/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3670
# Epoch 76/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3595
# Epoch 77/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3514
# Epoch 78/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3414
# Epoch 79/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3290
# Epoch 80/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3171
# Epoch 81/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3044
# Epoch 82/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2925
# Epoch 83/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2799
# Epoch 84/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2689
# Epoch 85/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2591
# Epoch 86/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2487
# Epoch 87/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2400
# Epoch 88/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2319
# Epoch 89/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2239
# Epoch 90/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2164
# Epoch 91/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2096
# Epoch 92/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2023
# Epoch 93/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1955
# Epoch 94/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1892
# Epoch 95/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1841
# Epoch 96/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1795
# Epoch 97/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1750
# Epoch 98/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1702
# Epoch 99/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1659
# Epoch 100/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1616
# Epoch 101/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1575
# Epoch 102/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1538
# Epoch 103/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1499
# Epoch 104/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1460
# Epoch 105/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1426
# Epoch 106/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1394
# Epoch 107/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1360
# Epoch 108/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1327
# Epoch 109/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1292
# Epoch 110/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1258
# Epoch 111/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1225
# Epoch 112/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1195
# Epoch 113/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1166
# Epoch 114/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1139
# Epoch 115/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1116
# Epoch 116/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1090
# Epoch 117/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1067
# Epoch 118/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1043
# Epoch 119/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1021
# Epoch 120/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1000
# Epoch 121/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0978
# Epoch 122/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0959
# Epoch 123/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0938
# Epoch 124/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0923
# Epoch 125/200
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0906
# Epoch 126/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0888
# Epoch 127/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0871
# Epoch 128/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0853
# Epoch 129/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0837
# Epoch 130/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0820
# Epoch 131/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0807
# Epoch 132/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0791
# Epoch 133/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0776
# Epoch 134/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0763
# Epoch 135/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0750
# Epoch 136/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0740
# Epoch 137/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0727
# Epoch 138/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0716
# Epoch 139/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0706
# Epoch 140/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0696
# Epoch 141/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0686
# Epoch 142/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0676
# Epoch 143/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0667
# Epoch 144/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0658
# Epoch 145/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0649
# Epoch 146/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0640
# Epoch 147/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0631
# Epoch 148/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0623
# Epoch 149/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0615
# Epoch 150/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0605
# Epoch 151/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0601
# Epoch 152/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0589
# Epoch 153/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0582
# Epoch 154/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0575
# Epoch 155/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0569
# Epoch 156/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0564
# Epoch 157/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0556
# Epoch 158/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0550
# Epoch 159/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0542
# Epoch 160/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0536
# Epoch 161/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0528
# Epoch 162/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0523
# Epoch 163/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0517
# Epoch 164/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0511
# Epoch 165/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0505
# Epoch 166/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0500
# Epoch 167/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0495
# Epoch 168/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0489
# Epoch 169/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0483
# Epoch 170/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0477
# Epoch 171/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0471
# Epoch 172/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0466
# Epoch 173/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0461
# Epoch 174/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0455
# Epoch 175/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0450
# Epoch 176/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0444
# Epoch 177/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0441
# Epoch 178/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0436
# Epoch 179/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0431
# Epoch 180/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0427
# Epoch 181/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0421
# Epoch 182/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0417
# Epoch 183/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0412
# Epoch 184/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0409
# Epoch 185/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0404
# Epoch 186/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0401
# Epoch 187/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0396
# Epoch 188/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0392
# Epoch 189/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0391
# Epoch 190/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0387
# Epoch 191/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0383
# Epoch 192/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0380
# Epoch 193/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0376
# Epoch 194/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0372
# Epoch 195/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0369
# Epoch 196/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0365
# Epoch 197/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0362
# Epoch 198/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0359
# Epoch 199/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0356
# Epoch 200/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0353

# %% [markdown]
# With the model trained, we can see how the model has classified the training data.

# %%
plt_cat_mc(X_train, y_train, model, classes)
# Out:
# 184/184 [==============================] - 0s 1ms/step
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %% [markdown]
# Above, the decision boundaries show how the model has partitioned the input space.  This very simple model has had no trouble classifying the training data. How did it accomplish this? Let's look at the network in more detail.
#
# Below, we will pull the trained weights from the model and use that to plot the function of each of the network units. Further down, there is a more detailed explanation of the results.

# %%
# Gather the trained parameters from the first layer
l1 = model.get_layer("L1")
W1, b1 = l1.get_weights()

# %%
# Plot the function of the first layer
plt_layer_relu(X_train, y_train.reshape(-1,), W1, b1, classes)
# Out:
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %%
# Gather the trained parameters from the output layer
l2 = model.get_layer("L2")
W2, b2 = l2.get_weights()
# Create the 'new features', the training examples after L1 transformation
Xl2 = np.maximum(0, np.dot(X_train,W1) + b1) # Relu function

plt_output_layer_linear(Xl2, y_train.reshape(-1,), W2, b2, classes,
                        x0_rng = (-0.25,np.amax(Xl2[:,0])), x1_rng = (-0.25,np.amax(Xl2[:,1])))
# Out:
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %% [markdown]
# ## Explanation
#
# Due to rng, the plots produced above would be slightly different from those in the images below, but the intuition is the same--- that the layers and their units are accomplishing different tasks in a classification problem.
#
# #### Layer 1
#
# <center>  <img  src="./images/C2_W2_mclass_layer1.png" width="800" />  </center>
#
# These plots show the function of Units 0 and 1 in the first layer of the network. The inputs are ($x_0,x_1$) on the axis. The output of the unit is represented by the color of the background. This is indicated by the color bar on the right of each graph. Notice that since these units are using a ReLu, the outputs do not necessarily fall between 0 and 1 and in this case are greater than 20 at their peaks.
# The contour lines in this graph show the transition point between the output, $a^{[1]}_j$ being zero and non-zero. Recall from the graph for a ReLu curve, the contour line in the graph is the inflection point in the ReLu.
#
# <center>  <img  src="./images/C2_W2_mclass_relu.png"  width="300" />  </center>
#
# * Unit 0 has separated classes 0 and 1 from classes 2 and 3. Points to the left of the line (classes 0 and 1) will output zero, while points to the right will output a value greater than zero.
#
# * Unit 1 has separated classes 0 and 2 from classes 1 and 3. Points above the line (classes 0 and 2 ) will output a zero, while points below will output a value greater than zero.

# %% [markdown]
# #### Layer 2, the output layer
#
# <center>  <img  src="./images/C2_W2_mclass_layer2.png" width="800" />  </center>
#
# The dots in these graphs are the training examples translated by the first layer. One way to think of this is that the first layer has created a new set of features for evaluation by the 2nd layer, which has four units. The axes in these plots are the outputs of the previous layer $a^{[1]}_0$ and $a^{[1]}_1$. As predicted above, classes 0 and 1 (blue and green) have $a^{[1]}_0 = 0$ while classes 0 and 2 (blue and orange) have $a^{[1]}_1 = 0$.
#
# Once again, the intensity of the background color indicates the highest values.
#
# * Unit 0 will produce its maximum value for values near (0,0), where class 0 (blue) has been mapped.
# * Unit 1 produces its highest values in the upper left corner selecting class 1 (green).
# * Unit 2 targets the lower right corner where class 2 (orange) resides.
# * Unit 3 produces its highest values in the upper right selecting our final class (purple).
#
# One other aspect that is not obvious from the graphs is that the values have been coordinated between the units. It is not sufficient for a unit to produce a maximum value for the class it is selecting for, since it must also be the highest value of all four units for the points in that class. This is done by the implied softmax function that is part of the loss function (`SparseCategoricalCrossEntropy`). Unlike other activation functions, the softmax works across all the outputs.
