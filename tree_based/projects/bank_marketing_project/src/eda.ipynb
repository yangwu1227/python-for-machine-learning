# %%
# Interactive 
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# Data 
import pandas as pd
import numpy as np
from numpy.random import seed

# Visualization
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# Machine Learning
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import accuracy_score
import xgboost as xgb

# %% [markdown]
# ## Global Settings

# %%
seed = 1227
rs = np.random.RandomState(seed)

# %% [markdown]
# ## Data

# %%
df = pd.read_csv("../data/raw/bank-additional-full.csv", sep=";")

# %%
# Memory usage in mb
df.memory_usage(deep=True).sum() / 1024**2
# Out:
# 30.26093578338623

# %%
# Shape
df.shape
# Out:
# (41188, 21)

# %% [markdown]
# ### Handle column names

# %%
# Convert columns names to snake case
df.columns = [col.lower().replace(".", "_") for col in df.columns]

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp_var_rate', 'cons_price_idx',
#        'cons_conf_idx', 'euribor3m', 'nr_employed', 'y'],
#       dtype='object')

# %% [markdown]
# ### Check first few rows

# %%
df.iloc[:5, :10]
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week
# 0   may         mon
# 1   may         mon
# 2   may         mon
# 3   may         mon
# 4   may         mon

# %%
df.iloc[:5, 10:]
# Out:
#    duration  campaign  pdays  previous     poutcome  emp_var_rate  \
# 0       261         1    999         0  nonexistent           1.1
# 1       149         1    999         0  nonexistent           1.1
# 2       226         1    999         0  nonexistent           1.1
# 3       151         1    999         0  nonexistent           1.1
# 4       307         1    999         0  nonexistent           1.1
#
#    cons_price_idx  cons_conf_idx  euribor3m  nr_employed   y
# 0          93.994          -36.4      4.857       5191.0  no
# 1          93.994          -36.4      4.857       5191.0  no
# 2          93.994          -36.4      4.857       5191.0  no
# 3          93.994          -36.4      4.857       5191.0  no
# 4          93.994          -36.4      4.857       5191.0  no

# %% [markdown]
# ## EDA
#
# ### Data Types

# %%
df.dtypes
# Out:
# age                 int64
# job                object
# marital            object
# education          object
# default            object
# housing            object
# loan               object
# contact            object
# month              object
# day_of_week        object
# duration            int64
# campaign            int64
# pdays               int64
# previous            int64
# poutcome           object
# emp_var_rate      float64
# cons_price_idx    float64
# cons_conf_idx     float64
# euribor3m         float64
# nr_employed       float64
# y                  object
# dtype: object

# %%
# String columns
str_col = {col: dtype for col, dtype in zip(df.columns, df.dtypes) if str(dtype).startswith('object')}
len(str_col)
str_col
# Out:
# 11
# {'job': dtype('O'),
#  'marital': dtype('O'),
#  'education': dtype('O'),
#  'default': dtype('O'),
#  'housing': dtype('O'),
#  'loan': dtype('O'),
#  'contact': dtype('O'),
#  'month': dtype('O'),
#  'day_of_week': dtype('O'),
#  'poutcome': dtype('O'),
#  'y': dtype('O')}

# %%
# Numeric columns
num_col = {col: dtype for col, dtype in zip(df.columns, df.dtypes) if str(dtype).startswith('int') or str(dtype).startswith('float')}
len(num_col)
num_col
# Out:
# 10
# {'age': dtype('int64'),
#  'duration': dtype('int64'),
#  'campaign': dtype('int64'),
#  'pdays': dtype('int64'),
#  'previous': dtype('int64'),
#  'emp_var_rate': dtype('float64'),
#  'cons_price_idx': dtype('float64'),
#  'cons_conf_idx': dtype('float64'),
#  'euribor3m': dtype('float64'),
#  'nr_employed': dtype('float64')}

# %% [markdown]
# ### Downcast Continuous Variables
#
# Some of the numeric variables can be downcasted to save memory:

# %%
for data_type in [np.int8, np.int16, np.int32]:
    {'max': np.iinfo(data_type).max, 'min': np.iinfo(data_type).min}
# Out:
# {'max': 127, 'min': -128}
# {'max': 32767, 'min': -32768}
# {'max': 2147483647, 'min': -2147483648}

# %%
for data_type in [np.float32, np.float64, np.float128]:
    {'max': np.finfo(data_type).max, 'min': np.finfo(data_type).min}
# Out:
# {'max': 3.4028235e+38, 'min': -3.4028235e+38}
# {'max': 1.7976931348623157e+308, 'min': -1.7976931348623157e+308}
# {'max': 1.189731495357231765e+4932, 'min': -1.189731495357231765e+4932}

# %%
# Max and min values for each numeric column
df[num_col.keys()].apply(lambda col: (col.max(), col.min()))
# Out:
#    age  duration  campaign  pdays  previous  emp_var_rate  cons_price_idx  \
# 0   98      4918        56    999         7           1.4          94.767
# 1   17         0         1      0         0          -3.4          92.201
#
#    cons_conf_idx  euribor3m  nr_employed
# 0          -26.9      5.045       5228.1
# 1          -50.8      0.634       4963.6

# %%
# Downcast integer columns
df[df.select_dtypes(include=['int64']).columns] = df.select_dtypes(include=['int64']).astype(np.int16)
# Campain can be cased as int8
df['campaign'] = df['campaign'].astype(np.int8)

# %%
# Downcast float columns
df[df.select_dtypes(include=['float']).columns] = df.select_dtypes(include=['float']).astype(np.float32)

# %%
# Sanity check
df[num_col.keys()].apply(lambda col: (col.max(), col.min()))
# Out:
#    age  duration  campaign  pdays  previous  emp_var_rate  cons_price_idx  \
# 0   98      4918        56    999         7           1.4       94.766998
# 1   17         0         1      0         0          -3.4       92.200996
#
#    cons_conf_idx  euribor3m  nr_employed
# 0     -26.900000      5.045  5228.100098
# 1     -50.799999      0.634  4963.600098

# %%
# New numeric columns dictionary
num_col = dict(df[num_col.keys()].dtypes)
num_col
# Out:
# {'age': dtype('int16'),
#  'duration': dtype('int16'),
#  'campaign': dtype('int8'),
#  'pdays': dtype('int16'),
#  'previous': dtype('int16'),
#  'emp_var_rate': dtype('float32'),
#  'cons_price_idx': dtype('float32'),
#  'cons_conf_idx': dtype('float32'),
#  'euribor3m': dtype('float32'),
#  'nr_employed': dtype('float32')}

# %%
# Check memory usage
df.memory_usage(deep=True).sum() / 1024**2
# Out:
# 28.25765895843506

# %% [markdown]
# The data types look correct for what they represent; we can now plot the continuous variables to get a better sense of their distribution. We may need to adjust the data types or conduct feature engineering for the economic indicator variables.

# %% [markdown]
# ### Univariate Plot

# %%
# Add a numeric label column for plotting, which will be processed later
df['label'] = df['y'].map({'yes': 1, 'no': 0}).astype(np.int8)

# %%
plt.rcParams['figure.figsize'] = (20, 10)
sns.pairplot(df[list(num_col.keys()) + ['label']], corner=True)

# %% [markdown]
# ### Univariate Correlation

# %%
df[list(num_col.keys()) + ['label']].corr().style.background_gradient(cmap='plasma')
# Out:
# <style type="text/css">
# #T_43b7d_row0_col0, #T_43b7d_row1_col1, #T_43b7d_row2_col2, #T_43b7d_row3_col3, #T_43b7d_row4_col4, #T_43b7d_row5_col5, #T_43b7d_row6_col6, #T_43b7d_row7_col7, #T_43b7d_row8_col8, #T_43b7d_row9_col9, #T_43b7d_row10_col10 {
#   background-color: #f0f921;
#   color: #000000;
# }
# #T_43b7d_row0_col1, #T_43b7d_row10_col0 {
#   background-color: #310597;
#   color: #f1f1f1;
# }
# #T_43b7d_row0_col2, #T_43b7d_row1_col7 {
#   background-color: #370499;
#   color: #f1f1f1;
# }
# #T_43b7d_row0_col3 {
#   background-color: #a11b9b;
#   color: #f1f1f1;
# }
# #T_43b7d_row0_col4, #T_43b7d_row1_col4 {
#   background-color: #ac2694;
#   color: #f1f1f1;
# }
# #T_43b7d_row0_col5 {
#   background-color: #8e0ca4;
#   color: #f1f1f1;
# }
# #T_43b7d_row0_col6 {
#   background-color: #5e01a6;
#   color: #f1f1f1;
# }
# #T_43b7d_row0_col7 {
#   background-color: #6a00a8;
#   color: #f1f1f1;
# }
# #T_43b7d_row0_col8, #T_43b7d_row2_col4 {
#   background-color: #9613a1;
#   color: #f1f1f1;
# }
# #T_43b7d_row0_col9 {
#   background-color: #9814a0;
#   color: #f1f1f1;
# }
# #T_43b7d_row0_col10 {
#   background-color: #8a09a5;
#   color: #f1f1f1;
# }
# #T_43b7d_row1_col0, #T_43b7d_row5_col0, #T_43b7d_row6_col0, #T_43b7d_row8_col10 {
#   background-color: #220690;
#   color: #f1f1f1;
# }
# #T_43b7d_row1_col2 {
#   background-color: #100788;
#   color: #f1f1f1;
# }
# #T_43b7d_row1_col3 {
#   background-color: #9e199d;
#   color: #f1f1f1;
# }
# #T_43b7d_row1_col5, #T_43b7d_row2_col6 {
#   background-color: #8707a6;
#   color: #f1f1f1;
# }
# #T_43b7d_row1_col6 {
#   background-color: #6001a6;
#   color: #f1f1f1;
# }
# #T_43b7d_row1_col8 {
#   background-color: #8d0ba5;
#   color: #f1f1f1;
# }
# #T_43b7d_row1_col9, #T_43b7d_row7_col10 {
#   background-color: #910ea3;
#   color: #f1f1f1;
# }
# #T_43b7d_row1_col10 {
#   background-color: #d9586a;
#   color: #f1f1f1;
# }
# #T_43b7d_row2_col0, #T_43b7d_row4_col7, #T_43b7d_row8_col1 {
#   background-color: #240691;
#   color: #f1f1f1;
# }
# #T_43b7d_row2_col1, #T_43b7d_row3_col0, #T_43b7d_row3_col4, #T_43b7d_row3_col7, #T_43b7d_row4_col2, #T_43b7d_row4_col3, #T_43b7d_row4_col5, #T_43b7d_row4_col6, #T_43b7d_row4_col8, #T_43b7d_row4_col9, #T_43b7d_row9_col10 {
#   background-color: #0d0887;
#   color: #f1f1f1;
# }
# #T_43b7d_row2_col3, #T_43b7d_row2_col8 {
#   background-color: #b22b8f;
#   color: #f1f1f1;
# }
# #T_43b7d_row2_col5, #T_43b7d_row7_col9 {
#   background-color: #b12a90;
#   color: #f1f1f1;
# }
# #T_43b7d_row2_col7, #T_43b7d_row6_col1 {
#   background-color: #350498;
#   color: #f1f1f1;
# }
# #T_43b7d_row2_col9, #T_43b7d_row4_col10 {
#   background-color: #ba3388;
#   color: #f1f1f1;
# }
# #T_43b7d_row2_col10, #T_43b7d_row5_col2 {
#   background-color: #6f00a8;
#   color: #f1f1f1;
# }
# #T_43b7d_row3_col1, #T_43b7d_row3_col10 {
#   background-color: #1b068d;
#   color: #f1f1f1;
# }
# #T_43b7d_row3_col2 {
#   background-color: #4b03a1;
#   color: #f1f1f1;
# }
# #T_43b7d_row3_col5 {
#   background-color: #c8437b;
#   color: #f1f1f1;
# }
# #T_43b7d_row3_col6 {
#   background-color: #7801a8;
#   color: #f1f1f1;
# }
# #T_43b7d_row3_col8 {
#   background-color: #cf4c74;
#   color: #f1f1f1;
# }
# #T_43b7d_row3_col9 {
#   background-color: #de5f65;
#   color: #f1f1f1;
# }
# #T_43b7d_row4_col0, #T_43b7d_row10_col6 {
#   background-color: #2e0595;
#   color: #f1f1f1;
# }
# #T_43b7d_row4_col1, #T_43b7d_row10_col5 {
#   background-color: #3c049b;
#   color: #f1f1f1;
# }
# #T_43b7d_row5_col1, #T_43b7d_row5_col10 {
#   background-color: #260591;
#   color: #f1f1f1;
# }
# #T_43b7d_row5_col3 {
#   background-color: #d5536f;
#   color: #f1f1f1;
# }
# #T_43b7d_row5_col4 {
#   background-color: #43039e;
#   color: #f1f1f1;
# }
# #T_43b7d_row5_col6 {
#   background-color: #fdac33;
#   color: #000000;
# }
# #T_43b7d_row5_col7 {
#   background-color: #8305a7;
#   color: #f1f1f1;
# }
# #T_43b7d_row5_col8 {
#   background-color: #f2f227;
#   color: #000000;
# }
# #T_43b7d_row5_col9 {
#   background-color: #f8df25;
#   color: #000000;
# }
# #T_43b7d_row6_col2 {
#   background-color: #6700a8;
#   color: #f1f1f1;
# }
# #T_43b7d_row6_col3 {
#   background-color: #b6308b;
#   color: #f1f1f1;
# }
# #T_43b7d_row6_col4 {
#   background-color: #7a02a8;
#   color: #f1f1f1;
# }
# #T_43b7d_row6_col5 {
#   background-color: #feb72d;
#   color: #000000;
# }
# #T_43b7d_row6_col7 {
#   background-color: #5102a3;
#   color: #f1f1f1;
# }
# #T_43b7d_row6_col8 {
#   background-color: #fba238;
#   color: #000000;
# }
# #T_43b7d_row6_col9 {
#   background-color: #ef7e50;
#   color: #f1f1f1;
# }
# #T_43b7d_row6_col10 {
#   background-color: #5b01a5;
#   color: #f1f1f1;
# }
# #T_43b7d_row7_col0 {
#   background-color: #5901a5;
#   color: #f1f1f1;
# }
# #T_43b7d_row7_col1, #T_43b7d_row7_col2 {
#   background-color: #2f0596;
#   color: #f1f1f1;
# }
# #T_43b7d_row7_col3 {
#   background-color: #9511a1;
#   color: #f1f1f1;
# }
# #T_43b7d_row7_col4, #T_43b7d_row8_col7 {
#   background-color: #9d189d;
#   color: #f1f1f1;
# }
# #T_43b7d_row7_col5 {
#   background-color: #bb3488;
#   color: #f1f1f1;
# }
# #T_43b7d_row7_col6 {
#   background-color: #7100a8;
#   color: #f1f1f1;
# }
# #T_43b7d_row7_col8 {
#   background-color: #cc4778;
#   color: #f1f1f1;
# }
# #T_43b7d_row8_col0 {
#   background-color: #280592;
#   color: #f1f1f1;
# }
# #T_43b7d_row8_col2 {
#   background-color: #6900a8;
#   color: #f1f1f1;
# }
# #T_43b7d_row8_col3 {
#   background-color: #d8576b;
#   color: #f1f1f1;
# }
# #T_43b7d_row8_col4 {
#   background-color: #3a049a;
#   color: #f1f1f1;
# }
# #T_43b7d_row8_col5 {
#   background-color: #f3f027;
#   color: #000000;
# }
# #T_43b7d_row8_col6 {
#   background-color: #f79143;
#   color: #f1f1f1;
# }
# #T_43b7d_row8_col9, #T_43b7d_row9_col8 {
#   background-color: #f5e926;
#   color: #000000;
# }
# #T_43b7d_row9_col0 {
#   background-color: #19068c;
#   color: #f1f1f1;
# }
# #T_43b7d_row9_col1 {
#   background-color: #1d068e;
#   color: #f1f1f1;
# }
# #T_43b7d_row9_col2 {
#   background-color: #6c00a8;
#   color: #f1f1f1;
# }
# #T_43b7d_row9_col3, #T_43b7d_row9_col6 {
#   background-color: #e26561;
#   color: #f1f1f1;
# }
# #T_43b7d_row9_col4 {
#   background-color: #2c0594;
#   color: #f1f1f1;
# }
# #T_43b7d_row9_col5 {
#   background-color: #f9dd25;
#   color: #000000;
# }
# #T_43b7d_row9_col7 {
#   background-color: #6100a7;
#   color: #f1f1f1;
# }
# #T_43b7d_row10_col1 {
#   background-color: #bd3786;
#   color: #f1f1f1;
# }
# #T_43b7d_row10_col2 {
#   background-color: #16078a;
#   color: #f1f1f1;
# }
# #T_43b7d_row10_col3 {
#   background-color: #5c01a6;
#   color: #f1f1f1;
# }
# #T_43b7d_row10_col4 {
#   background-color: #ce4b75;
#   color: #f1f1f1;
# }
# #T_43b7d_row10_col7 {
#   background-color: #5002a2;
#   color: #f1f1f1;
# }
# #T_43b7d_row10_col8, #T_43b7d_row10_col9 {
#   background-color: #41049d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_43b7d_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >age</th>
#       <th class="col_heading level0 col1" >duration</th>
#       <th class="col_heading level0 col2" >campaign</th>
#       <th class="col_heading level0 col3" >pdays</th>
#       <th class="col_heading level0 col4" >previous</th>
#       <th class="col_heading level0 col5" >emp_var_rate</th>
#       <th class="col_heading level0 col6" >cons_price_idx</th>
#       <th class="col_heading level0 col7" >cons_conf_idx</th>
#       <th class="col_heading level0 col8" >euribor3m</th>
#       <th class="col_heading level0 col9" >nr_employed</th>
#       <th class="col_heading level0 col10" >label</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_43b7d_level0_row0" class="row_heading level0 row0" >age</th>
#       <td id="T_43b7d_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_43b7d_row0_col1" class="data row0 col1" >-0.000866</td>
#       <td id="T_43b7d_row0_col2" class="data row0 col2" >0.004594</td>
#       <td id="T_43b7d_row0_col3" class="data row0 col3" >-0.034369</td>
#       <td id="T_43b7d_row0_col4" class="data row0 col4" >0.024365</td>
#       <td id="T_43b7d_row0_col5" class="data row0 col5" >-0.000371</td>
#       <td id="T_43b7d_row0_col6" class="data row0 col6" >0.000857</td>
#       <td id="T_43b7d_row0_col7" class="data row0 col7" >0.129372</td>
#       <td id="T_43b7d_row0_col8" class="data row0 col8" >0.010767</td>
#       <td id="T_43b7d_row0_col9" class="data row0 col9" >-0.017725</td>
#       <td id="T_43b7d_row0_col10" class="data row0 col10" >0.030399</td>
#     </tr>
#     <tr>
#       <th id="T_43b7d_level0_row1" class="row_heading level0 row1" >duration</th>

# %% [markdown]
# * Interestingly, the higher the number of contacts performed during the campaign, the less likely that the client subscribes.
#
# * Consumer price index is highly and positively correlated with employment variation rate, as expected.
#
# * Last contact duration is also highly correlated with the label in the positive direction. However, the duration of the contact is not known before a call is performed. **Thus, this input should be discarded if the intention is to have a realistic predictive model.**
#
# * The label is also correlated with economic indicator variables.

# %%
df.drop('label', axis=1, inplace=True)

# %% [markdown]
# ### Examine Categories in String Columns

# %%
for col in str_col.keys():
    print(df[col].value_counts(dropna=False), '\n')
# Out:
# admin.           10422
# blue-collar       9254
# technician        6743
# services          3969
# management        2924
# retired           1720
# entrepreneur      1456
# self-employed     1421
# housemaid         1060
# unemployed        1014
# student            875
# unknown            330
# Name: job, dtype: int64
#
# married     24928
# single      11568
# divorced     4612
# unknown        80
# Name: marital, dtype: int64
#
# university.degree      12168
# high.school             9515
# basic.9y                6045
# professional.course     5243
# basic.4y                4176
# basic.6y                2292
# unknown                 1731
# illiterate                18
# Name: education, dtype: int64
#
# no         32588
# unknown     8597
# yes            3
# Name: default, dtype: int64
#
# yes        21576
# no         18622
# unknown      990
# Name: housing, dtype: int64
#
# no         33950
# yes         6248
# unknown      990
# Name: loan, dtype: int64
#
# cellular     26144
# telephone    15044
# Name: contact, dtype: int64
#
# may    13769
# jul     7174
# aug     6178
# jun     5318
# nov     4101
# apr     2632
# oct      718
# sep      570
# mar      546
# dec      182
# Name: month, dtype: int64
#
# thu    8623
# mon    8514
# wed    8134
# tue    8090
# fri    7827
# Name: day_of_week, dtype: int64
#
# nonexistent    35563
# failure         4252
# success         1373
# Name: poutcome, dtype: int64
#
# no     36548
# yes     4640
# Name: y, dtype: int64

# %% [markdown]
# As can be seen, missing values in the categorical variables are all coded with the "unknown" label, which can be treated as a class on its own.

# %%
# No explicit missing values
df.isna().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp_var_rate      0
# cons_price_idx    0
# cons_conf_idx     0
# euribor3m         0
# nr_employed       0
# y                 0
# dtype: int64

# %% [markdown]
# ## Train Test Split
#
# Based on the EDA, we see that the dataset is highly imbalanced, and so we should preserve the imbalanced nature of the data by using stratified shuffle split, which preserves the distribution of the two classes--- 'yes' and 'no'.

# %%
df.y.value_counts(dropna=False)
# Out:
# no     36548
# yes     4640
# Name: y, dtype: int64

# %% [markdown]
# Compute the imbalanced degree:

# %%
print(
    'minority class proportions', ((df.y.value_counts(dropna=False)[1] / df.shape[0]) * 100).round(2), '\n'
    'majority class proportions', ((df.y.value_counts(dropna=False)[0] / df.shape[0]) * 100).round(2)
)
# Out:
# minority class proportions 11.27
# majority class proportions 88.73

# %% [markdown]
# The data is moderately imbalanced based on [Google's ML developer course](https://developers.google.com/machine-learning/data-prep/construct/sampling-splitting/imbalanced-data).

# %%
# Stratified shuffle split based on label
sss = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=rs)
type(sss)
# Out:
# sklearn.model_selection._split.StratifiedShuffleSplit

# %%
for train_index, test_index in sss.split(X=df, y=df['y']):
    train = df.loc[train_index]
    test = df.loc[test_index]

# %% [markdown]
# Sanity check for class proportions:

# %%
print(
    'train minority class proportions', ((train.y.value_counts(dropna=False)[1] / train.shape[0]) * 100).round(2), '\n'
    'train majority class proportions', ((train.y.value_counts(dropna=False)[0] / train.shape[0]) * 100).round(2)
)
# Out:
# train minority class proportions 11.27
# train majority class proportions 88.73

# %%
print(
    'test minority class proportions', ((test.y.value_counts(dropna=False)[1] / test.shape[0]) * 100).round(2), '\n'
    'test majority class proportions', ((test.y.value_counts(dropna=False)[0] / test.shape[0]) * 100).round(2)
)
# Out:
# test minority class proportions 11.26
# test majority class proportions 88.74

# %%
# Write to disk
train.drop('y', axis=1).to_parquet('../data/train_test/train_X.parquet', index=False)
pd.DataFrame(train['y']).to_parquet('../data/train_test/train_y.parquet', index=False)
test.drop('y', axis=1).to_parquet('../data/train_test/test_X.parquet', index=False)
pd.DataFrame(test['y']).to_parquet('../data/train_test/test_y.parquet', index=False)

# %% [markdown]
# ## PCA
#
# We will conduct PCA on the continuous columns to explore the training data in more depth:

# %%
# Number of unique values
for col in train.select_dtypes(include=['number']).columns:
    print(col, train[col].unique().size)
# Out:
# age 78
# duration 1472
# campaign 40
# pdays 27
# previous 8
# emp_var_rate 10
# cons_price_idx 26
# cons_conf_idx 26
# euribor3m 313
# nr_employed 11

# %%
pca_train = train.select_dtypes(include=['number'])
pca_train
# Out:
#        age  duration  campaign  pdays  previous  emp_var_rate  cons_price_idx  \
# 29024   44       921         2    999         1          -1.8       93.074997
# 21104   35       139         3    999         0           1.4       93.444000
# 40121   66       317         1    999         0          -1.7       94.214996
# 33953   39       143         1    999         1          -1.8       92.892998
# 29684   57       108         1    999         0          -1.8       93.074997
# ...    ...       ...       ...    ...       ...           ...             ...
# 31321   36       197         1    999         1          -1.8       92.892998
# 555     40       195         1    999         0           1.1       93.994003
# 18652   54        20        27    999         0           1.4       93.917999
# 26693   33        98         1    999         0          -0.1       93.199997
# 20700   45       325         1    999         0           1.4       93.444000
#
#        cons_conf_idx  euribor3m  nr_employed
# 29024     -47.099998      1.405  5099.100098
# 21104     -36.099998      4.963  5228.100098
# 40121     -40.299999      0.835  4991.600098
# 33953     -46.200001      1.281  5099.100098
# 29684     -47.099998      1.405  5099.100098
# ...              ...        ...          ...
# 31321     -46.200001      1.334  5099.100098
# 555       -36.400002      4.857  5191.000000
# 18652     -42.700001      4.968  5228.100098
# 26693     -42.000000      4.076  5195.799805
# 20700     -36.099998      4.965  5228.100098
#
# [32950 rows x 10 columns]

# %%
# Standardize the data
scaled_pca_train = StandardScaler().fit_transform(pca_train)
scaled_pca_train.shape
scaled_pca_train
# Out:
# (32950, 10)
# array([[ 0.3837289 ,  2.5655444 , -0.2049196 , ..., -1.4276062 ,
#         -1.2773857 , -0.937277  ],
#        [-0.47956282, -0.45744798,  0.15706511, ...,  0.94999534,
#          0.7731883 ,  0.8446928 ],
#        [ 2.4939976 ,  0.23065005, -0.56690425, ...,  0.04218367,
#         -1.6058927 , -2.422252  ],
#        ...,
#        [ 1.3429419 , -0.9174686 ,  8.844697  , ..., -0.47656608,
#          0.77607   ,  0.8446928 ],
#        [-0.67140543, -0.6159425 , -0.56690425, ..., -0.325264  ,
#          0.26198584,  0.39850563],
#        [ 0.47965017,  0.26157582, -0.56690425, ...,  0.94999534,
#          0.77434117,  0.8446928 ]], dtype=float32)

# %%
# PCA and keep all 10 components
pca = PCA(n_components=10)
pca.fit(scaled_pca_train)
# Out:
# PCA(n_components=10)

# %% [markdown]
# ### Scree Plot

# %%
plt.plot(np.arange(pca.n_components_) + 1, np.cumsum(pca.explained_variance_ratio_), 'o-', linewidth=2, color='blue')
plt.title('Scree Plot')
plt.xlabel('Principal Component')
plt.ylim(0, 1.0)
plt.ylabel('Cumulative Variance Explained')
plt.show();

# %%
perc = pd.DataFrame(
    {
        'pc': ['PC' + str(i) for i in range(1, 11)],
        'Cumulative Variance Explained': np.cumsum(pca.explained_variance_ratio_)
    }
)
perc
# Out:
#      pc  Cumulative Variance Explained
# 0   PC1                       0.389973
# 1   PC2                       0.525545
# 2   PC3                       0.633379
# 3   PC4                       0.738209
# 4   PC5                       0.831370
# 5   PC6                       0.915528
# 6   PC7                       0.958214
# 7   PC8                       0.996452
# 8   PC9                       0.998945
# 9  PC10                       1.000000

# %% [markdown]
# * The first two PC's explain ~$52\%$ of variance
#
# * The first five PC's explain ~$83\%$ of variance
#
# * It takes six PC's to explain > $90\%$ of variance

# %% [markdown]
# ### 3D Plot Using First Three PC's

# %%
# Construct the principal components
scaled_pca_train.shape, pca.components_.T.shape
pc = scaled_pca_train @ pca.components_.T
# Out:
# ((32950, 10), (10, 10))

# %%
pc = pd.DataFrame(pc, columns=['PC ' + str(i) for i in range(1, 11)])
# Add label for plotting
pc['label'] = train['y'].to_numpy()
pc
# Out:
#            PC 1      PC 2      PC 3      PC 4      PC 5      PC 6      PC 7  \
# 0      2.665079 -0.280649  0.116353  1.901938  1.962124 -0.499436 -0.363358
# 1     -1.378075  0.140612 -0.174746 -0.336872 -0.707530  0.830467 -0.537251
# 2      1.978237  0.294768 -1.796768 -0.404335  1.166119 -1.461991  2.570037
# 3      2.750602 -0.642080  0.479435 -0.102534 -0.293463 -0.892966 -0.409100
# 4      1.996753 -1.152253 -0.941098 -0.714701  0.508652 -1.728115  0.056641
# ...         ...       ...       ...       ...       ...       ...       ...
# 32945  2.741360 -0.694668  0.627571  0.147821 -0.301313 -0.695669 -0.414335
# 32946 -1.277233  0.486749 -0.509583  0.146006 -0.730536  0.094890  0.430698
# 32947 -2.409008  0.126879  2.997570 -5.650083  5.638117  2.236919 -0.316076
# 32948 -0.102452 -0.811947  0.108866  0.022130 -0.969259 -0.031028 -0.639247
# 32949 -1.287955  0.442814 -1.126474  0.297341 -0.311960  0.202375 -0.589372
#
#            PC 8      PC 9     PC 10 label
# 0      1.122656  0.049416 -0.028979    no
# 1      0.101113 -0.193173 -0.082685    no
# 2     -0.451037 -0.108527  0.001645   yes
# 3      1.048815 -0.040503 -0.077868    no
# 4     -0.503119  0.006959 -0.021182    no
# ...         ...       ...       ...   ...
# 32945  1.062384 -0.037972 -0.052601    no
# 32946  0.026776 -0.017145  0.065043    no
# 32947 -0.014353 -0.047131  0.087389    no
# 32948 -0.142552  0.080942  0.166760    no
# 32949  0.100931 -0.193818 -0.090877    no
#
# [32950 rows x 11 columns]

# %%
fig = px.scatter_3d(pc, x='PC 1', y='PC 2', z='PC 3', color='label', width=1000, height=500)
fig.update_layout(
    margin=dict(l=15, r=15, t=20, b=20),
    paper_bgcolor="LightSteelBlue",
)
fig.write_html('../outputs/plots/first_three_pc.html') # Write interactive 3d plot to html file
fig.show();

# %% [markdown]
# ### Loadings
#
# Examine the loadings for the first 6 principal components:

# %%
loadings = pca.components_.T
loadings.shape
# Out:
# (10, 10)

# %%
loadings = pd.DataFrame(loadings, columns=['PC ' + str(i) for i in range(1, 11)], index=pca_train.columns)
loadings.iloc[:, :6]
# Out:
#                     PC 1      PC 2      PC 3      PC 4      PC 5      PC 6
# age            -0.000424  0.253527 -0.608769 -0.314052  0.444609 -0.517215
# duration        0.026839  0.075707 -0.129628  0.760833  0.584544  0.231485
# campaign       -0.099167 -0.006088  0.379275 -0.536425  0.623138  0.412202
# pdays          -0.230559 -0.625937 -0.250947 -0.037116  0.054010  0.021796
# previous        0.307693  0.472965  0.282402  0.013927 -0.027224 -0.145566
# emp_var_rate   -0.487563  0.163655  0.087263  0.055944 -0.029677 -0.075396
# cons_price_idx -0.364749  0.279193  0.271029  0.106497  0.049151 -0.249720
# cons_conf_idx  -0.100951  0.432705 -0.494245 -0.127603 -0.245736  0.645518
# euribor3m      -0.489962  0.149419  0.000473  0.037960 -0.063213  0.004549
# nr_employed    -0.469680 -0.013089  0.025928  0.031410 -0.031516 -0.050690

# %% [markdown]
# * Age is pretty important to PC3 trough PC6
#
# * Duration is import to PC4 and PC5 but it should be dropped
#
# * The economic indicator variables are important to many PC's
#
# * Employment variation rate, Euribor 3 month rate, number of employees, and consumer confidence index are contributors to the first PC

# %% [markdown]
# ### PCA Dimension Guess

# %%
guessed_dim = PCA(n_components='mle').fit(scaled_pca_train).n_components_
print('The number of dimension based on Minka\'s MLE is', guessed_dim)
# Out:
# The number of dimension based on Minka's MLE is 9

# %% [markdown]
# This is the true dimensionality of the data base on Bayesian model selection.

# %% [markdown]
# ## Feature Importance For Continuous Variables

# %%
# XGBoost parameters
params = {
    'n_estimators': 100,
    'max_depth': 3,
    'learning_rate': 0.1,
    'objective': 'binary:logistic',
    'booster': 'gbtree',
    'verbosity': 1,
    'subsample': 0.5,
    'random_state': rs,
    'n_jobs': -1
    }  

# XGBoost model
xgb_clf = xgb.XGBClassifier(**params)
xgb_clf
# Out:
# XGBClassifier(base_score=None, booster='gbtree', callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, gamma=None,
#               gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=3,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=-1,
#               num_parallel_tree=None, predictor=None, random_state=1727090694,
#               reg_alpha=None, reg_lambda=None, ...)

# %%
train_X = train[num_col.keys()]
train_y = train['y'].map({'yes': 1, 'no': 0}).astype(np.int8)
train_X.shape, train_y.shape
# Out:
# ((32950, 10), (32950,))

# %%
# XGBoost model
xgb_clf.fit(X=train_X, y=train_y)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.1, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=3, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=-1, num_parallel_tree=1, predictor='auto',
#               random_state=1829624311, reg_alpha=0, reg_lambda=1, ...)

# %%
# Prediction
pred_y = xgb_clf.predict(test[num_col.keys()])
# Accuracy
print('XGBoost model accuracy score: {0:0.4f}'. format(accuracy_score(pred_y, test.y.map({'yes': 1, 'no': 0}).astype(np.int8))))
# Out:
# XGBoost model accuracy score: 0.9158

# %% [markdown]
# ### Plot

# %%
xgb.plot_importance(xgb_clf)
plt.savefig('../outputs/plots/feature_importance_numerical_variable.png', dpi=500, bbox_inches='tight')
plt.show();
