# %% [markdown]
# # Simple Neural Network
#
#    <center> <img  src="./images/C2_W1_CoffeeRoasting.png" width="600" />   <center/>

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use("utils/deeplearning.mplstyle")

import logging

import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from utils.lab_coffee_utils import (
    load_coffee_data,
    plt_layer,
    plt_network,
    plt_output_unit,
    plt_roast,
)

logging.getLogger("tensorflow").setLevel(logging.ERROR)
tf.autograph.set_verbosity(0)

print(tf.__version__)
# Out:
# 2.12.0

# %% [markdown]
# ## DataSet

# %%
X, Y = load_coffee_data()
# Two features or variables
print(X.shape, Y.shape)
# Out:
# (200, 2) (200, 1)

# %% [markdown]
# Let's plot the coffee roasting data below. The two features are Temperature in Celsius and Duration in minutes. [Coffee Roasting at Home](https://www.merchantsofgreencoffee.com/how-to-roast-green-coffee-in-your-oven/) suggests that the duration is best kept between 12 and 15 minutes while the temp should be between 175 and 260 degrees Celsius. Of course, as temperature rises, the duration should shrink.

# %%
plt.rcParams["figure.figsize"] = (13, 10)
plt_roast(X, Y)

# %% [markdown]
# ### Normalize Data
#
# Fitting the weights to the data (back-propagation) will proceed more quickly if the data is normalized where features in the data are placed on a similar range. The procedure below uses a Keras [normalization layer](https://keras.io/api/layers/preprocessing_layers/numerical/normalization/), which is a a **preprocessing layer** that normalizes continuous features. It has the following steps:
#
# - create a 'Normalization Layer', which is not a layer in the model but a preprocessing layer
# - 'adapt' the data, which means that it learns the mean and variance of the data set and saves the values internally
# - shift and scale inputs into a distribution centered around 0 with standard deviation 1 by calling `(input - mean) / sqrt(var)` at runtime
#
# It is important to apply normalization to any future data that utilizes the learned model, using the same `mean` and `var` learned from the training data. If not, then we have data leakage.

# %%
print(
    f"Temperature Max, Min pre normalization: {np.max(X[:,0]):0.2f}, {np.min(X[:,0]):0.2f}"
)
print(
    f"Duration    Max, Min pre normalization: {np.max(X[:,1]):0.2f}, {np.min(X[:,1]):0.2f}"
)

# The argument axis=-1 means that the mean and variance are computed along the last axis of the input tensor (columns)
norm_l = tf.keras.layers.Normalization(axis=-1)
norm_l.adapt(X)  # Learns mean and variance from training data
Xn = norm_l(X)

print(
    f"Temperature Max, Min post normalization: {np.max(Xn[:,0]):0.2f}, {np.min(Xn[:,0]):0.2f}"
)
print(
    f"Duration    Max, Min post normalization: {np.max(Xn[:,1]):0.2f}, {np.min(Xn[:,1]):0.2f}"
)
# Out:
# Temperature Max, Min pre normalization: 284.99, 151.32
# Duration    Max, Min pre normalization: 15.45, 11.51
# Temperature Max, Min post normalization: 1.66, -1.69
# Duration    Max, Min post normalization: 1.79, -1.70

# %% [markdown]
# Tile/copy our data to increase the training set size and reduce the number of training epochs.

# %%
# Repeat the data 1000 times
Xt = np.tile(Xn, (1000, 1))
Yt = np.tile(Y, (1000, 1))
print(Xt.shape, Yt.shape)
# Out:
# (200000, 2) (200000, 1)

# %%
# Imbalanced data
plt.hist(Yt)
plt.show()

# %%
# Feature plots
plt.scatter(Xt[:, 0], Xt[:, 1], c=Yt, cmap="bwr", alpha=0.1)
plt.show()

# %% [markdown]
# ## Tensorflow Model

# %% [markdown]
# ### Model
#    <center> <img  src="./images/C2_W1_RoastingNetwork.PNG" width="300" />   <center/>

# %% [markdown]
# There are two layers with sigmoid activation functions in the network:

# %%
tf.random.set_seed(1234)  # Applied to achieve consistent results
model = Sequential(
    [
        tf.keras.Input(shape=(2,)),
        Dense(units=3, activation="sigmoid", name="layer1"),
        Dense(units=1, activation="sigmoid", name="layer2"),
    ]
)

# %% [markdown]
# * **Note 1:** The `tf.keras.Input(shape=(2,))` layer specifies the expected shape of the input. This allows Tensorflow to size the weights and bias parameters at this point.  This is useful when exploring Tensorflow models. This statement can be omitted in practice and Tensorflow will size the network parameters when the input data is specified in the `model.fit` statement.
#
# * **Note 2:** Including the sigmoid activation in the final layer is not considered best practice. It would instead be accounted for in the loss which improves numerical stability. This will be described in more detail later.
#
# The `model.summary()` provides a description of the network:

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  layer1 (Dense)              (None, 3)                 9
#
#  layer2 (Dense)              (None, 1)                 4
#
# ...
# Total params: 13
# Trainable params: 13
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# The parameter counts shown in the summary correspond to the number of elements in the weight and bias arrays as shown below.

# %%
L1_num_params = (
    2 * 3 + 3
)  # W1 parameters (times 2 since there are 2 input features)  + b1 parameters (three neurons or units)
L2_num_params = (
    3 * 1 + 1
)  # W2 parameters (times 1 since there is 1 activation vector a1)  + b2 parameters (1 neuron or unit)
print("L1 params = ", L1_num_params, ", L2 params = ", L2_num_params)
# Out:
# L1 params =  9 , L2 params =  4

# %% [markdown]
# Let's examine the weights and biases Tensorflow has instantiated.  The weights $W$ should be of size (number of features in input, number of units in the layer) while the bias $b$ size should match the number of units in the layer:
#
# - In the first layer with 3 units, we expect W to have a size of (2, 3) and $b$ should be a vector with 3 elements.
# - In the second layer with 1 unit, we expect W to have a size of (3, 1) and $b$ should be a vector with 1 element.

# %%
W1, b1 = model.get_layer("layer1").get_weights()
W2, b2 = model.get_layer("layer2").get_weights()

print(f"W1{W1.shape}:\n", W1, f"\nb1{b1.shape}:", b1, "\n\n")
print(f"W2{W2.shape}:\n", W2, f"\nb2{b2.shape}:", b2)
# Out:
# W1(2, 3):
#  [[ 0.77  0.12  1.07]
#  [-0.88 -0.63 -0.01]]
# b1(3,): [0. 0. 0.]
#
#
# W2(3, 1):
#  [[ 1.17]
#  [-0.82]
#  [-0.13]]
# b2(1,): [0.]

# %% [markdown]
# For now:
#
# - The `model.compile` statement defines a loss function and specifies a compile optimization.
# - The `model.fit` statement runs gradient descent and fits the weights to the data.

# %%
model.compile(
    loss=tf.keras.losses.BinaryCrossentropy(),
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),
)

model.fit(
    Xt,
    Yt,
    # The epochs is a hyperparameter that defines the number times that the learning algorithm will work through the entire training dataset
    # An epoch is an iteration over the entire x and y data provided
    epochs=10,
)
# Out:
# Epoch 1/10
# 6250/6250 [==============================] - 5s 790us/step - loss: 0.1889
# Epoch 2/10
# 6250/6250 [==============================] - 5s 740us/step - loss: 0.1350
# Epoch 3/10
# 6250/6250 [==============================] - 4s 708us/step - loss: 0.1250
# Epoch 4/10
# 6250/6250 [==============================] - 4s 696us/step - loss: 0.1147
# Epoch 5/10
# 6250/6250 [==============================] - 6s 955us/step - loss: 0.0485
# Epoch 6/10
# 6250/6250 [==============================] - 6s 937us/step - loss: 0.0165
# Epoch 7/10
# 6250/6250 [==============================] - 5s 870us/step - loss: 0.0108
# Epoch 8/10
# 6250/6250 [==============================] - 4s 714us/step - loss: 0.0076
# Epoch 9/10
# 6250/6250 [==============================] - 5s 828us/step - loss: 0.0054
# Epoch 10/10
# 6250/6250 [==============================] - 7s 1ms/step - loss: 0.0039

# %% [markdown]
# #### Updated Weights
# After fitting, the weights have been updated:

# %%
W1, b1 = model.get_layer("layer1").get_weights()
W2, b2 = model.get_layer("layer2").get_weights()

print("W1:\n", W1, "\nb1:", b1, "\n\n")
print("W2:\n", W2, "\nb2:", b2)
# Out:
# W1:
#  [[-1.71e+01 -1.04e+01  1.50e-02]
#  [-1.43e+01 -2.24e-01 -8.30e+00]]
# b1: [ -2.46 -11.36 -10.44]
#
#
# W2:
#  [[ 30.63]
#  [-42.99]
#  [-38.29]]
# b2: [-8.74]

# %% [markdown]
# Next, we will load some saved weights from a previous training run. This is so that this notebook remains robust to changes in Tensorflow over time. Different training runs can produce somewhat different results and the discussion below applies to a particular solution. Feel free to re-run the notebook with this cell commented out to see the difference.

# %%
W1 = np.array([[-8.94, 0.29, 12.89], [-0.17, -7.34, 10.79]])
b1 = np.array([-9.87, -9.28, 1.01])
W2 = np.array([[-31.38], [-27.86], [-32.79]])
b2 = np.array([15.54])
model.get_layer("layer1").set_weights([W1, b1])
model.get_layer("layer2").set_weights([W2, b2])

# %% [markdown]
# ### Predictions
#
#    <center><img src="./images/C2_W1_RoastingDecision.PNG" width="600" />   <center/>

# %% [markdown]
# Once the model is trained, we can then use it to make predictions. Recall that the output of our model is a probability. In this case, it is the probability of a good roast. To make a decision, one must apply the probability to a threshold. In this case, we will use 0.5.
#
# The model is expecting one or more examples where examples are in the rows of matrix. In this case, we have two features so the matrix will be (m,2) where m is the number of examples or rows. Recall, we have normalized the input features so we must normalize our test data as well. To make a prediction, we apply the `predict` method.

# %%
X_test = np.array(
    [
        [200, 13.9],  # Positive example
        [200, 17],
    ]
)  # Negative example

# Using mean and variance from training data
X_testn = norm_l(X_test)

predictions = model.predict(X_testn)
print("predictions = \n", predictions)
# Out:
# 1/1 [==============================] - 0s 150ms/step
# predictions =
#  [[9.63e-01]
#  [3.03e-08]]

# %% [markdown]
# #### Epochs and Batches
#
# In the `compile` statement above, the number of `epochs` was set to 10. This specifies that the entire data set should be applied during training 10 times.  During training, we see output describing the progress of training that looks like this:
# ```
# Epoch 1/10
# 6250/6250 [==============================] - 6s 910us/step - loss: 0.1782
# ```
# The first line, `Epoch 1/10`, describes which epoch the model is currently running. For efficiency, the training data set is broken into 'batches'. The default size of a batch in Tensorflow is 32. There are 200000 examples in our expanded data set or 6250 ($32\times6250$) batches. The notation on the 2nd line `6250/6250 [====` is describing which batch has been executed. Below is a visualization comparing epochs (a single passing of the entire training set through the network), batch size, and iterations:
#
# <center> <img  src="images/epochs_iterations_batchsize.png" width="600" />   </center>

# %% [markdown]
# To convert the probabilities to a decision, we apply a threshold:

# %%
yhat = np.zeros_like(predictions)

for i in range(len(predictions)):
    if predictions[i] >= 0.5:
        yhat[i] = 1
    else:
        yhat[i] = 0

print(f"decisions = \n{yhat}")
# Out:
# decisions =
# [[1.]
#  [0.]]

# %% [markdown]
# This can be accomplished more succinctly:

# %%
yhat = (predictions >= 0.5).astype(int)
print(f"decisions = \n{yhat}")
# Out:
# decisions =
# [[1]
#  [0]]

# %% [markdown]
# ## Layer Functions
# Let's examine the functions of the units to determine their role in the coffee roasting decision. We will plot the output of each node for all values of the inputs (duration,temp). Each unit is a logistic function whose output can range from zero to one. The shading in the graph represents the output value.

# %%
plt_layer(
    X,
    Y.reshape(
        -1,
    ),
    W1,
    b1,
    norm_l,
)

# %% [markdown]
# The shading shows that each unit is responsible for a different "bad roast" region. First, unit 0 has larger values when the temperature is too low. Then, unit 1 has larger values when the duration is too short. Unit 2 has larger values for bad combinations of time and temperature. It is worth noting that the network learned these functions on its own through the process of gradient descent. They are very much the same sort of functions a person might choose to make the same decisions.

# %% [markdown]
# The function plot of the final layer is a bit more difficult to visualize. It's inputs are the output of the first layer. We know that the first layer uses sigmoids so their output range is between zero and one. We can create a 3-D plot that calculates the output for all possible combinations of the three inputs. The floating white points, which may be hard to see, show the output values with low probabilities corresponding to 'bad roasts.' Below, the maximum output is in areas where the three inputs are small values corresponding to 'good roast' areas.

# %%
plt_output_unit(W2, b2)

# %% [markdown]
# The final graph shows the whole network in action:
#
# * The left graph is the raw output of the final layer represented by the blue shading. This is overlaid on the training data represented by the X's and O's.
#
# * The right graph is the output of the network after a decision threshold. The X's and O's here correspond to decisions made by the network.

# %%
netf = lambda x: model.predict(norm_l(x))
plt_network(X, Y, netf)
# Out:
# ...
# 1/1 [==============================] - 0s 21ms/step
# ...
# ...
# 7/7 [==============================] - 0s 1ms/step
