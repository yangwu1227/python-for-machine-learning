# %%
import sys
import polars as pl

sys.path.append("..")
from src.ab_testing import analyze_campaigns

# %% [markdown]
# ## Data

# %%
data = pl.read_parquet("../data/campaigns.parquet")

data
# Out:
# shape: (60, 10)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ campaign_ ┆ date      ┆ spend_usd ┆ impressio ┆ … ┆ searches_ ┆ view_cont ┆ add_to_ca ┆ purchase │
# │ name      ┆ ---       ┆ ---       ┆ ns_count  ┆   ┆ count     ┆ ent_count ┆ rt_count  ┆ _count   │
# │ ---       ┆ datetime[ ┆ i16       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---      │
# │ cat       ┆ ns]       ┆           ┆ i32       ┆   ┆ i32       ┆ i32       ┆ i32       ┆ i32      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ Control   ┆ 2019-01-0 ┆ 2280      ┆ 82702     ┆ … ┆ 2290      ┆ 2159      ┆ 1819      ┆ 618      │
# │ Campaign  ┆ 8         ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆ 00:00:00  ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ Control   ┆ 2019-02-0 ┆ 1757      ┆ 121040    ┆ … ┆ 2033      ┆ 1841      ┆ 1219      ┆ 511      │
# │ Campaign  ┆ 8         ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆ 00:00:00  ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ Control   ┆ 2019-03-0 ┆ 2343      ┆ 131711    ┆ … ┆ 1737      ┆ 1549      ┆ 1134      ┆ 372      │
# │ Campaign  ┆ 8         ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆ 00:00:00  ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ Control   ┆ 2019-04-0 ┆ 1940      ┆ 72878     ┆ … ┆ 1042      ┆ 982       ┆ 1183      ┆ 340      │
# │ Campaign  ┆ 8         ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆ 00:00:00  ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ Control   ┆ 2019-05-0 ┆ 1835      ┆ null      ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ Campaign  ┆ 8         ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆ 00:00:00  ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ Test      ┆ 2019-08-2 ┆ 2311      ┆ 80841     ┆ … ┆ 2037      ┆ 1046      ┆ 346       ┆ 284      │
# │ Campaign  ┆ 6         ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆ 00:00:00  ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ Test      ┆ 2019-08-2 ┆ 2915      ┆ 111469    ┆ … ┆ 2976      ┆ 2552      ┆ 992       ┆ 771      │
# │ Campaign  ┆ 7         ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆ 00:00:00  ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ Test      ┆ 2019-08-2 ┆ 2247      ┆ 54627     ┆ … ┆ 2432      ┆ 1281      ┆ 1009      ┆ 721      │
# │ Campaign  ┆ 8         ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆ 00:00:00  ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ Test      ┆ 2019-08-2 ┆ 2805      ┆ 67444     ┆ … ┆ 1920      ┆ 1240      ┆ 1168      ┆ 677      │
# │ Campaign  ┆ 9         ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆ 00:00:00  ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ Test      ┆ 2019-08-3 ┆ 1977      ┆ 120203    ┆ … ┆ 2978      ┆ 1625      ┆ 1034      ┆ 572      │
# │ Campaign  ┆ 0         ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆ 00:00:00  ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
ab_test_cols = [col for col in data.columns if col.endswith("count")] + ["reach"]
group_col = "campaign_name"

campaign_data = {
    "control": {
        col: data.filter(pl.col(group_col) == "Control Campaign")[col].to_numpy()
        for col in ab_test_cols
    },
    "test": {
        col: data.filter(pl.col(group_col) == "Test Campaign")[col].to_numpy()
        for col in ab_test_cols
    },
}

# %% [markdown]
# ## Brunner Munzel Test
#
# The estimated treatment effect is computed relative to the control group; that is, the treatment group is the group of interest.

# %%
analyze_campaigns(campaign_data)
# Out:
# GT(_tbl_data=shape: (7, 5)
# ┌──────────────────────┬───────────┬─────────────────────────┬───────────┬─────────────────────────┐
# │ field                ┆ stat      ┆ estimated_treatment_eff ┆ p_value   ┆ conclusion              │
# │ ---                  ┆ ---       ┆ ect_tes…                ┆ ---       ┆ ---                     │
# │ str                  ┆ f64       ┆ ---                     ┆ f64       ┆ str                     │
# │                      ┆           ┆ f64                     ┆           ┆                         │
# ╞══════════════════════╪═══════════╪═════════════════════════╪═══════════╪═════════════════════════╡
# │ impressions_count    ┆ -5.205193 ┆ 0.198851                ┆ 0.000004  ┆ Reject null hypothesis  │
# │                      ┆           ┆                         ┆           ┆ of no t…                │
# │ website_clicks_count ┆ 1.518469  ┆ 0.612644                ┆ 0.134444  ┆ Fail to reject null     │
# │                      ┆           ┆                         ┆           ┆ hypothesis…             │
# │ searches_count       ┆ 1.299847  ┆ 0.602299                ┆ 0.201306  ┆ Fail to reject null     │
# │                      ┆           ┆                         ┆           ┆ hypothesis…             │
# │ view_content_count   ┆ -0.104471 ┆ 0.491954                ┆ 0.917165  ┆ Fail to reject null     │
# │                      ┆           ┆                         ┆           ┆ hypothesis…             │
# │ add_to_cart_count    ┆ -4.217082 ┆ 0.236782                ┆ 0.000107  ┆ Reject null hypothesis  │
# │                      ┆           ┆                         ┆           ┆ of no t…                │
# │ purchase_count       ┆ -0.059547 ┆ 0.495402                ┆ 0.952732  ┆ Fail to reject null     │
# │                      ┆           ┆                         ┆           ┆ hypothesis…             │
# │ reach                ┆ -6.058103 ┆ 0.173563                ┆ 2.0450e-7 ┆ Reject null hypothesis  │
# │                      ┆           ┆                         ┆           ┆ of no t…                │
# └──────────────────────┴───────────┴─────────────────────────┴───────────┴─────────────────────────┘, _body=<great_tables._gt_data.Body object at 0x10d5582d0>, _boxhead=Boxhead([ColInfo(var='field', type=<ColInfoTypeEnum.default: 1>, column_label='field', column_align='left', column_width=None), ColInfo(var='stat', type=<ColInfoTypeEnum.default: 1>, column_label='stat', column_align='right', column_width=None), ColInfo(var='estimated_treatment_effect_test_minus_control', type=<ColInfoTypeEnum.default: 1>, column_label='estimated_treatment_effect_test_minus_control', column_align='right', column_width=None), ColInfo(var='p_value', type=<ColInfoTypeEnum.default: 1>, column_label='p_value', column_align='right', column_width=None), ColInfo(var='conclusion', type=<ColInfoTypeEnum.default: 1>, column_label='conclusion', column_align='left', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x119587090>, _spanners=Spanners([]), _heading=Heading(title=None, subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[StyleInfo(locname=LocBody(columns=None, rows=<Expr ['[(col("p_value")) < (dyn float…'] at 0x10D58E210>), grpname=None, colname='field', rownum=0, colnum=None, styles=[CellStyleFill(color='#90EE90')]), StyleInfo(locname=LocBody(columns=None, rows=<Expr ['[(col("p_value")) < (dyn float…'] at 0x10D58E210>), grpname=None, colname='field', rownum=4, colnum=None, styles=[CellStyleFill(color='#90EE90')]), StyleInfo(locname=LocBody(columns=None, rows=<Expr ['[(col("p_value")) < (dyn float…'] at 0x10D58E210>), grpname=None, colname='field', rownum=6, colnum=None, styles=[CellStyleFill(color='#90EE90')]), StyleInfo(locname=LocBody(columns=None, rows=<Expr ['[(col("p_value")) < (dyn float…'] at 0x10D58E210>), grpname=None, colname='stat', rownum=0, colnum=None, styles=[CellStyleFill(color='#90EE90')]), StyleInfo(locname=LocBody(columns=None, rows=<Expr ['[(col("p_value")) < (dyn float…'] at 0x10D58E210>), grpname=None, colname='stat', rownum=4, colnum=None, styles=[CellStyleFill(color='#90EE90')]), StyleInfo(locname=LocBody(columns=None, rows=<Expr ['[(col("p_value")) < (dyn float…'] at 0x10D58E210>), grpname=None, colname='stat', rownum=6, colnum=None, styles=[CellStyleFill(color='#90EE90')]), StyleInfo(locname=LocBody(columns=None, rows=<Expr ['[(col("p_value")) < (dyn float…'] at 0x10D58E210>), grpname=None, colname='estimated_treatment_effect_test_minus_control', rownum=0, colnum=None, styles=[CellStyleFill(color='#90EE90')]), StyleInfo(locname=LocBody(columns=None, rows=<Expr ['[(col("p_value")) < (dyn float…'] at 0x10D58E210>), grpname=None, colname='estimated_treatment_effect_test_minus_control', rownum=4, colnum=None, styles=[CellStyleFill(color='#90EE90')]), StyleInfo(locname=LocBody(columns=None, rows=<Expr ['[(col("p_value")) < (dyn float…'] at 0x10D58E210>), grpname=None, colname='estimated_treatment_effect_test_minus_control', rownum=6, colnum=None, styles=[CellStyleFill(color='#90EE90')]), StyleInfo(locname=LocBody(columns=None, rows=<Expr ['[(col("p_value")) < (dyn float…'] at 0x10D58E210>), grpname=None, colname='p_value', rownum=0, colnum=None, styles=[CellStyleFill(color='#90EE90')]), StyleInfo(locname=LocBody(columns=None, rows=<Expr ['[(col("p_value")) < (dyn float…'] at 0x10D58E210>), grpname=None, colname='p_value', rownum=4, colnum=None, styles=[CellStyleFill(color='#90EE90')]), StyleInfo(locname=LocBody(columns=None, rows=<Expr ['[(col("p_value")) < (dyn float…'] at 0x10D58E210>), grpname=None, colname='p_value', rownum=6, colnum=None, styles=[CellStyleFill(color='#90EE90')]), StyleInfo(locname=LocBody(columns=None, rows=<Expr ['[(col("p_value")) < (dyn float…'] at 0x10D58E210>), grpname=None, colname='conclusion', rownum=0, colnum=None, styles=[CellStyleFill(color='#90EE90')]), StyleInfo(locname=LocBody(columns=None, rows=<Expr ['[(col("p_value")) < (dyn float…'] at 0x10D58E210>), grpname=None, colname='conclusion', rownum=4, colnum=None, styles=[CellStyleFill(co ...

# %% [markdown]
# ## Key Metrics
#
# <center>
#
# | **Metric**                         | **Formula**                                                   | **Description**                                         |
# |------------------------------------|---------------------------------------------------------------|---------------------------------------------------------|
# | Click-Through Rate (CTR)           | $ \text{CTR} = \frac{\text{Clicks}}{\text{Impressions}} \times 100 $                          | Percentage of impressions that result in a click.       |
# | Conversion Rate (CR)               | $ \text{CR} = \frac{\text{Purchases}}{\text{Clicks}} \times 100 $                             | Percentage of clicks that result in a purchase.          |
# | Cost Per Click (CPC)               | $ \text{CPC} = \frac{\text{Amount Spent}}{\text{Clicks}} $                                 | Cost paid per click on an ad.                           |
# | Cost Per Thousand Impressions (CPM)| $ \text{CPM} = \frac{\text{Amount Spent}}{\text{Impressions}} \times 1000 $                   | Cost to generate 1,000 impressions.                     |
# | Cost Per Acquisition (CPA)         | $ \text{CPA} = \frac{\text{Amount Spent}}{\text{Purchases}} $                              | Cost to acquire a customer.                             |
# | Engagement Rate                    | $ \text{Engagement Rate} = \frac{\text{Add to Carts}}{\text{Impressions}} $                 | Proportion of impressions leading to an add-to-cart action. |
#
# </center>

# %%
with pl.SQLContext(data=data, eager=True) as sql_context:
    query = """ 
            SELECT
                campaign_name,
                CAST(website_clicks_count AS FLOAT) / NULLIF(CAST(impressions_count AS FLOAT), 0) AS click_through_rate,
                CAST(purchase_count AS FLOAT) / NULLIF(CAST(website_clicks_count AS FLOAT), 0) AS conversion_rate,
                CAST(spend_usd AS FLOAT) / NULLIF(CAST(website_clicks_count AS FLOAT), 0) AS cost_per_click,
                CAST(spend_usd AS FLOAT) / NULLIF(CAST(impressions_count AS FLOAT), 0) * 1000 AS cost_per_thousand_impressions,
                CAST(spend_usd AS FLOAT) / NULLIF(CAST(purchase_count AS FLOAT), 0) AS cost_per_acquisition,
                CAST(add_to_cart_count AS FLOAT) / NULLIF(CAST(impressions_count AS FLOAT), 0) AS engagement_rate
            FROM
                data;
            """
    key_metrics = sql_context.execute(query)

key_metrics
# Out:
# shape: (60, 7)
# ┌──────────────┬─────────────┬─────────────┬─────────────┬─────────────┬─────────────┬─────────────┐
# │ campaign_nam ┆ click_throu ┆ conversion_ ┆ cost_per_cl ┆ cost_per_th ┆ cost_per_ac ┆ engagement_ │
# │ e            ┆ gh_rate     ┆ rate        ┆ ick         ┆ ousand_impr ┆ quisition   ┆ rate        │
# │ ---          ┆ ---         ┆ ---         ┆ ---         ┆ essions     ┆ ---         ┆ ---         │
# │ cat          ┆ f64         ┆ f64         ┆ f64         ┆ ---         ┆ f64         ┆ f64         │
# │              ┆             ┆             ┆             ┆ f64         ┆             ┆             │
# ╞══════════════╪═════════════╪═════════════╪═════════════╪═════════════╪═════════════╪═════════════╡
# │ Control      ┆ 0.084835    ┆ 0.088084    ┆ 0.324971    ┆ 27.568862   ┆ 3.68932     ┆ 0.021995    │
# │ Campaign     ┆             ┆             ┆             ┆             ┆             ┆             │
# │ Control      ┆ 0.067003    ┆ 0.063009    ┆ 0.216646    ┆ 14.515863   ┆ 3.438356    ┆ 0.010071    │
# │ Campaign     ┆             ┆             ┆             ┆             ┆             ┆             │
# │ Control      ┆ 0.049411    ┆ 0.05716     ┆ 0.360018    ┆ 17.788947   ┆ 6.298387    ┆ 0.00861     │
# │ Campaign     ┆             ┆             ┆             ┆             ┆             ┆             │
# │ Control      ┆ 0.042057    ┆ 0.11093     ┆ 0.632953    ┆ 26.61983    ┆ 5.705882    ┆ 0.016233    │
# │ Campaign     ┆             ┆             ┆             ┆             ┆             ┆             │
# │ Control      ┆ null        ┆ null        ┆ null        ┆ null        ┆ null        ┆ null        │
# │ Campaign     ┆             ┆             ┆             ┆             ┆             ┆             │
# │ …            ┆ …           ┆ …           ┆ …           ┆ …           ┆ …           ┆ …           │
# │ Test         ┆ 0.047253    ┆ 0.074346    ┆ 0.604974    ┆ 28.586979   ┆ 8.137324    ┆ 0.00428     │
# │ Campaign     ┆             ┆             ┆             ┆             ┆             ┆             │
# │ Test         ┆ 0.057729    ┆ 0.119814    ┆ 0.452991    ┆ 26.150768   ┆ 3.780804    ┆ 0.008899    │
# │ Campaign     ┆             ┆             ┆             ┆             ┆             ┆             │
# │ Test         ┆ 0.149084    ┆ 0.088531    ┆ 0.275909    ┆ 41.133505   ┆ 3.116505    ┆ 0.018471    │
# │ Campaign     ┆             ┆             ┆             ┆             ┆             ┆             │
# │ Test         ┆ 0.113442    ┆ 0.088485    ┆ 0.366619    ┆ 41.59006    ┆ 4.143279    ┆ 0.017318    │
# │ Campaign     ┆             ┆             ┆             ┆             ┆             ┆             │
# │ Test         ┆ 0.036596    ┆ 0.13003     ┆ 0.44942     ┆ 16.447177   ┆ 3.456294    ┆ 0.008602    │
# │ Campaign     ┆             ┆             ┆             ┆             ┆             ┆             │
# └──────────────┴─────────────┴─────────────┴─────────────┴─────────────┴─────────────┴─────────────┘

# %%
campaign_metrics = {
    "control": {
        col: key_metrics.filter(pl.col("campaign_name") == "Control Campaign")[
            col
        ].to_numpy()
        for col in key_metrics.columns
        if col != "campaign_name"
    },
    "test": {
        col: key_metrics.filter(pl.col("campaign_name") == "Test Campaign")[
            col
        ].to_numpy()
        for col in key_metrics.columns
        if col != "campaign_name"
    },
}

# %%
analyze_campaigns(campaign_metrics)
# Out:
# GT(_tbl_data=shape: (6, 5)
# ┌────────────────────────┬───────────┬────────────────────────┬────────────┬───────────────────────┐
# │ field                  ┆ stat      ┆ estimated_treatment_ef ┆ p_value    ┆ conclusion            │
# │ ---                    ┆ ---       ┆ fect_tes…              ┆ ---        ┆ ---                   │
# │ str                    ┆ f64       ┆ ---                    ┆ f64        ┆ str                   │
# │                        ┆           ┆ f64                    ┆            ┆                       │
# ╞════════════════════════╪═══════════╪════════════════════════╪════════════╪═══════════════════════╡
# │ click_through_rate     ┆ 4.667065  ┆ 0.778161               ┆ 0.00002    ┆ Reject null           │
# │                        ┆           ┆                        ┆            ┆ hypothesis of no t…   │
# │ conversion_rate        ┆ -1.020837 ┆ 0.421839               ┆ 0.312101   ┆ Fail to reject null   │
# │                        ┆           ┆                        ┆            ┆ hypothesis…           │
# │ cost_per_click         ┆ -0.224175 ┆ 0.482759               ┆ 0.823428   ┆ Fail to reject null   │
# │                        ┆           ┆                        ┆            ┆ hypothesis…           │
# │ cost_per_thousand_impr ┆ 7.795429  ┆ 0.868966               ┆ 7.3073e-10 ┆ Reject null           │
# │ essions                ┆           ┆                        ┆            ┆ hypothesis of no t…   │
# │ cost_per_acquisition   ┆ 1.115567  ┆ 0.583908               ┆ 0.269316   ┆ Fail to reject null   │
# │                        ┆           ┆                        ┆            ┆ hypothesis…           │
# │ engagement_rate        ┆ 0.444758  ┆ 0.534483               ┆ 0.65836    ┆ Fail to reject null   │
# │                        ┆           ┆                        ┆            ┆ hypothesis…           │
# └────────────────────────┴───────────┴────────────────────────┴────────────┴───────────────────────┘, _body=<great_tables._gt_data.Body object at 0x11957d490>, _boxhead=Boxhead([ColInfo(var='field', type=<ColInfoTypeEnum.default: 1>, column_label='field', column_align='left', column_width=None), ColInfo(var='stat', type=<ColInfoTypeEnum.default: 1>, column_label='stat', column_align='right', column_width=None), ColInfo(var='estimated_treatment_effect_test_minus_control', type=<ColInfoTypeEnum.default: 1>, column_label='estimated_treatment_effect_test_minus_control', column_align='right', column_width=None), ColInfo(var='p_value', type=<ColInfoTypeEnum.default: 1>, column_label='p_value', column_align='right', column_width=None), ColInfo(var='conclusion', type=<ColInfoTypeEnum.default: 1>, column_label='conclusion', column_align='left', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x11d348950>, _spanners=Spanners([]), _heading=Heading(title=None, subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[StyleInfo(locname=LocBody(columns=None, rows=<Expr ['[(col("p_value")) < (dyn float…'] at 0x11D342B10>), grpname=None, colname='field', rownum=0, colnum=None, styles=[CellStyleFill(color='#90EE90')]), StyleInfo(locname=LocBody(columns=None, rows=<Expr ['[(col("p_value")) < (dyn float…'] at 0x11D342B10>), grpname=None, colname='field', rownum=3, colnum=None, styles=[CellStyleFill(color='#90EE90')]), StyleInfo(locname=LocBody(columns=None, rows=<Expr ['[(col("p_value")) < (dyn float…'] at 0x11D342B10>), grpname=None, colname='stat', rownum=0, colnum=None, styles=[CellStyleFill(color='#90EE90')]), StyleInfo(locname=LocBody(columns=None, rows=<Expr ['[(col("p_value")) < (dyn float…'] at 0x11D342B10>), grpname=None, colname='stat', rownum=3, colnum=None, styles=[CellStyleFill(color='#90EE90')]), StyleInfo(locname=LocBody(columns=None, rows=<Expr ['[(col("p_value")) < (dyn float…'] at 0x11D342B10>), grpname=None, colname='estimated_treatment_effect_test_minus_control', rownum=0, colnum=None, styles=[CellStyleFill(color='#90EE90')]), StyleInfo(locname=LocBody(columns=None, rows=<Expr ['[(col("p_value")) < (dyn float…'] at 0x11D342B10>), grpname=None, colname='estimated_treatment_effect_test_minus_control', rownum=3, colnum=None, styles=[CellStyleFill(color='#90EE90')]), StyleInfo(locname=LocBody(columns=None, rows=<Expr ['[(col("p_value")) < (dyn float…'] at 0x11D342B10>), grpname=None, colname='p_value', rownum=0, colnum=None, styles=[CellStyleFill(color='#90EE90')]), StyleInfo(locname=LocBody(columns=None, rows=<Expr ['[(col("p_value")) < (dyn float…'] at 0x11D342B10>), grpname=None, colname='p_value', rownum=3, colnum=None, styles=[CellStyleFill(color='#90EE90')]), StyleInfo(locname=LocBody(columns=None, rows=<Expr ['[(col("p_value")) < (dyn float…'] at 0x11D342B10>), grpname=None, colname='conclusion', rownum=0, colnum=None, styles=[CellStyleFill(color='#90EE90')]), StyleInfo(locname=LocBody(columns=None, rows=<Expr ['[(col("p_value")) < (dyn float…'] at 0x11D342B10>), grpname=None, colname='conclusion', rownum=3, colnum=None, styles=[CellStyleFill(color='#90EE90')]), StyleInfo(locname=LocBody(columns=None, rows=<Expr ['[(col("p_value")) >= (dyn floa…'] at 0x11D348090>), grpname=None, colname='field', rownum=1, colnum=None, styles=[CellStyleFill(color='#FF6666')]), StyleInfo(locname=LocBody(columns=None, rows=<Expr ['[(col("p_value")) >= (dyn floa…'] at 0x11D348090>), grpname=None, colname='field', rownum=2, colnum=None, styles=[CellStyleFill(color='#FF6666')]), StyleInfo(locname=LocBody(columns=None, rows=<Expr ['[(col("p_value")) >= (dyn floa…'] at 0x11D348090>), grpname=None, colname='field', rownum=4, colnum=None, styles=[CellStyleFill(color='#FF6666')]), StyleInfo(locname=LocBody(columns=None, rows=<Expr ['[(col("p_value")) >= (dyn floa…'] at 0x11D348090>), grpname=None, colname='field', rownum=5, colnum=None, styles=[CellStyleFill(color='#FF6666')]), StyleInfo(locname=LocBo ...
